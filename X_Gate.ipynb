# %%
from qiskit import *

# %%
from qiskit.tools.visualization import plot_bloch_multivector

# %%
circuit = QuantumCircuit(1,1)

# %%
circuit.x(0)

# %%
circuit.measure([0],[0])

# %%
simulator = Aer.get_backend('statevector_simulator')

# %%
result = execute(circuit, backend=simulator).result()

# %%
statevector = result.get_statevector()

# %%
print(statevector)
# Out:
# [0.+0.j 1.+0.j]

# %%
circuit.draw(output='mpl')

# %%
plot_bloch_multivector(statevector)

# %%
circuit = QuantumCircuit(1,1)
circuit.y(0)
circuit.measure([0],[0])
simulator = Aer.get_backend('statevector_simulator')
result = execute(circuit, backend = simulator).result()
statevector = result.get_statevector()
print(statevector)
# Out:
# [0.+0.j 0.+1.j]

# %%
circuit.draw('mpl')

# %%
plot_bloch_multivector(statevector)

# %%
circuit.measure([0],[0])

# %%
backend = Aer.get_backend('qasm_simulator')

# %%
result = execute(circuit, backend=backend, shots=1024).result()

# %%
counts = result.get_counts()

# %%
from qiskit.tools.visualization import plot_histogram

# %%
plot_histogram(counts)

# %%
IBMQ.load_account()
# Out:
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
provider = IBMQ.get_provider('ibm-q')

# %%
qcomp = provider.get_backend('ibmq_16_melbourne')

# %%
job = execute(circuit, backend = qcomp)

# %%
from qiskit.tools.monitor import job_monitor

# %%
job_monitor(job)
# Out:
# Job Status: job incurred error

# %%
result = job.result()
# Out:
# ---------------------------------------------------------------------------
# IBMQJobFailureError                       Traceback (most recent call last)
# <ipython-input-27-e7dce18b5e49> in <module>
# ----> 1 result = job.result()
#
# ~\Anaconda3\lib\site-packages\qiskit\providers\ibmq\job\ibmqjob.py in result(self, timeout, wait, partial, refresh)
#     272                 raise IBMQJobFailureError(
#     273                     'Unable to retrieve result for job {}. Job has failed. '
# --> 274                     'Use job.error_message() to get more details.'.format(self.job_id()))
#     275
#     276         return self._retrieve_result(refresh=refresh)
#
# IBMQJobFailureError: 'Unable to retrieve result for job 5eff76291234f7001abd268d. Job has failed. Use job.error_message() to get more details.'
